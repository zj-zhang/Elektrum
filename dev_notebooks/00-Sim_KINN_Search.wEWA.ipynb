# %% [markdown]
# # Probablistic model building genetic algorithm

# %%
# %cd ..
# Out:
# /mnt/ceph/users/zzhang/CRISPR_pred/crispr_kinn

# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()
from src.kinetic_model import KineticModel, modelSpace_to_modelParams, modelParams_to_modelSpace
from src.neural_network_builder import KineticEigenModelBuilder, KineticNeuralNetworkBuilder
from src.model_spaces import get_sim_model_space as get_model_space
from src.neural_search import search_env, get_reward_pipeline
#from src.data import get_sim_deplete_data as get_data
from src.runAmber_simkinn import get_data
from src.reload import reload_from_dir
# Out:
# Using TensorFlow backend.
# 0.1.2-pmbga

# %%
import warnings
warnings.filterwarnings('ignore')
import time
from datetime import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import yaml

import scipy.stats as ss
import pandas as pd
import numpy as np
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import shutil
import os
import pickle
import gc
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load data

# %%
data_fp = "data/sim_data/22-06-28_synth_data_depl/test_1_depl.tsv"
param_fp = "data/sim_data/22-06-28_synth_data_depl/params.yaml"
logbase = 10
(x_train, y_train), (x_test, y_test) = get_data(fp=data_fp, logbase=logbase)

# %%
x_train.shape
# Out:
# (16000, 50, 4)

# %% [markdown]
# ## Setup AMBER

# %%
import amber
print(amber.__version__)
from amber.architect import pmbga
from amber.architect import ModelSpace, Operation
# Out:
# 0.1.2-pmbga

# %%
kinn_model_space = get_model_space(use_sink_state=False)
print(kinn_model_space)
# Out:
# StateSpace with 7 layers and 1 total combinations

# %%
controller = pmbga.ProbaModelBuildGeneticAlgo(
            model_space=kinn_model_space,
            buffer_type='population',
            buffer_size=125,   # buffer size controlls the max history going back
            batch_size=1,     # batch size does not matter in this case; all arcs will be retrieved
            ewa_beta=0.6,      # ewa_beta approximates the moving average over 1/(1-ewa_beta) prev points
        )

# %% [markdown]
# ## A For-Loop that does the work for `amber.architect.trainEnv`

# %%
wd = "outputs/notebook_2"
# trainEnv parameters
evo_params = dict(
    model_fn = KineticNeuralNetworkBuilder,
    samps_per_gen = 2,   # how many arcs to sample in each generation; important
    max_gen = 750,
    patience = 300,
    n_warmup_gen = 0,
    train_data = (x_train, y_train),
    test_data = (x_test, y_test)
)

# manager configs
# this learning rate is trickier than usual, for eigendecomp to work
initial_learning_rate = 0.05
batch_size = 2000
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10*int(20000/batch_size), # decrease every 5 epochs
    decay_rate=0.9,
    staircase=True)

if logbase is None:
    output_op = lambda: tf.keras.layers.Lambda(lambda x: x, name="output_nominal")
else:
    output_op = lambda: tf.keras.layers.Lambda(lambda x: tf.math.log(x)/np.log(logbase), name="output_log")

manager_kwargs={
    'optimizer': lambda: tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=1.),
    'output_op': output_op,
    'n_feats': 50,
    'n_channels': 4,
    'batch_size': batch_size,
    'epochs': 100,
    'earlystop': 5,
    'verbose': 0
}

# %%
controller, hist, stat_df = search_env(
    controller=controller, 
    wd = wd,
    evo_params=evo_params, 
    manager_kwargs=manager_kwargs
)
# Out:
# datapoints:  1 / total:  2
# [02:16:48] Gen 0 - Mean fitness 0.573 - Best 0.6511 - PostVar 5.939 - Time 9.85
# datapoints:  3 / total:  4
- Mean fitness 0.789 - Best 0.8834 - PostVar 4.775 - Time 9.00
# datapoints:  109 / total:  250
# [03:06:58] Gen 259 - Mean fitness 0.780 - Best 0.8834 - PostVar 4.715 - Time 11.70
# datapoints:  117 / total:  250
# [03:07:07] Gen 260 - Mean fitness 0.777 - Best 0.8834 - PostVar 4.470 - Time 8.60
# datapoints:  91 / total:  250
# [03:07:18] Gen 261 - Mean fitness 0.789 - Best 0.8834 - PostVar 4.684 - Time 11.72
# datapoints:  102 / total:  250
# [03:07:30] Gen 262 - Mean fitness 0.783 - Best 0.8834 - PostVar 4.382 - Time 11.20
# datapoints:  117 / total:  250
# [03:07:43] Gen 263 - Mean fitness 0.776 - Best 0.8834 - PostVar 4.584 - Time 13.47
# datapoints:  140 / total:  250
# [03:07:57] Gen 264 - Mean fitness 0.770 - Best 0.8834 - PostVar 4.465 - Time 13.51
# datapoints:  142 / total:  250
# [03:08:12] Gen 265 - Mean fitness 0.769 - Best 0.8834 - PostVar 4.411 - Time 14.67
# datapoints:  169 / total:  250
# [03:08:23] Gen 266 - Mean fitness 0.758 - Best 0.8834 - PostVar 4.413 - Time 11.14
# datapoints:  153 / total:  250
# [03:08:36] Gen 267 - Mean fitness 0.765 - Best 0.8834 - PostVar 4.560 - Time 13.10
# datapoints:  102 / total:  250
# [03:08:50] Gen 268 - Mean fitness 0.784 - Best 0.8834 - PostVar 4.595 - Time 14.15
# datapoints:  104 / total:  250
# [03:09:02] Gen 269 - Mean fitness 0.782 - Best 0.8834 - PostVar 4.116 - Time 12.31
# datapoints:  139 / total:  250
# [03:09:15] Gen 270 - Mean fitness 0.770 - Best 0.8834 - PostVar 4.827 - Time 12.69
# datapoints:  117 / total:  250
# [03:09:31] Gen 271 - Mean fitness 0.777 - Best 0.8834 - PostVar 4.786 - Time 15.27
# datapoints:  97 / total:  250
# [03:09:44] Gen 272 - Mean fitness 0.788 - Best 0.8834 - PostVar 4.419 - Time 13.63
# datapoints:  144 / total:  250
# [03:09:54] Gen 273 - Mean fitness 0.769 - Best 0.8834 - PostVar 4.755 - Time 9.22
# datapoints:  96 / total:  250
# [03:10:08] Gen 274 - Mean fitness 0.789 - Best 0.8834 - PostVar 4.274 - Time 14.01
# datapoints:  92 / total:  250
# [03:10:18] Gen 275 - Mean fitness 0.791 - Best 0.8834 - PostVar 4.362 - Time 10.03
# datapoints:  148 / total:  250
# [03:10:28] Gen 276 - Mean fitness 0.768 - Best 0.8834 - PostVar 4.497 - Time 10.51
# datapoints:  165 / total:  250
# [03:10:39] Gen 277 - Mean fitness 0.763 - Best 0.8834 - PostVar 4.531 - Time 10.26
# datapoints:  112 / total:  250
# [03:10:49] Gen 278 - Mean fitness 0.780 - Best 0.8834 - PostVar 4.298 - Time 10.14
# datapoints:  123 / total:  250
# [03:11:01] Gen 279 - Mean fitness 0.776 - Best 0.8834 - PostVar 4.265 - Time 11.97
# datapoints:  109 / total:  250
# [03:11:11] Gen 280 - Mean fitness 0.783 - Best 0.8834 - PostVar 4.604 - Time 9.70
# datapoints:  101 / total:  250
# [03:11:22] Gen 281 - Mean fitness 0.790 - Best 0.8834 - PostVar 4.291 - Time 11.04
# datapoints:  57 / total:  250
# [03:11:38] Gen 282 - Mean fitness 0.805 - Best 0.8834 - PostVar 4.109 - Time 15.89
# datapoints:  124 / total:  250
# [03:11:50] Gen 283 - Mean fitness 0.778 - Best 0.8834 - PostVar 4.441 - Time 11.79
# datapoints:  70 / total:  250
# [03:12:02] Gen 284 - Mean fitness 0.802 - Best 0.8834 - PostVar 4.165 - Time 12.12
# datapoints:  56 / total:  250
# [03:12:15] Gen 285 - Mean fitness 0.807 - Best 0.8834 - PostVar 4.512 - Time 13.25
# datapoints:  74 / total:  250
# [03:12:31] Gen 286 - Mean fitness 0.800 - Best 0.8834 - PostVar 4.355 - Time 15.42
# datapoints:  54 / total:  250
# [03:12:46] Gen 287 - Mean fitness 0.809 - Best 0.8834 - PostVar 4.782 - Time 15.20
# datapoints:  117 / total:  250
# [03:12:58] Gen 288 - Mean fitness 0.782 - Best 0.8834 - PostVar 4.496 - Time 11.69
# datapoints:  135 / total:  250
# [03:13:08] Gen 289 - Mean fitness 0.775 - Best 0.8834 - PostVar 4.457 - Time 10.00
# datapoints:  117 / total:  250
# [03:13:18] Gen 290 - Mean fitness 0.783 - Best 0.8834 - PostVar 4.594 - Time 10.66
# datapoints:  155 / total:  250
# [03:13:27] Gen 291 - Mean fitness 0.769 - Best 0.8834 - PostVar 4.445 - Time 8.39
# datapoints:  137 / total:  250
# [03:13:37] Gen 292 - Mean fitness 0.774 - Best 0.8834 - PostVar 4.774 - Time 10.34
# datapoints:  157 / total:  250
# [03:13:47] Gen 293 - Mean fitness 0.768 - Best 0.8834 - PostVar 4.181 - Time 10.06
# datapoints:  140 / total:  250
# [03:13:58] Gen 294 - Mean fitness 0.772 - Best 0.8834 - PostVar 4.551 - Time 10.30
# datapoints:  108 / total:  250
# [03:14:12] Gen 295 - Mean fitness 0.789 - Best 0.8834 - PostVar 4.332 - Time 14.09
# datapoints:  95 / total:  250
# [03:14:21] Gen 296 - Mean fitness 0.794 - Best 0.8834 - PostVar 4.839 - Time 8.90
# datapoints:  112 / total:  250
# [03:14:32] Gen 297 - Mean fitness 0.788 - Best 0.8834 - PostVar 4.464 - Time 10.69
# datapoints:  117 / total:  250
# [03:14:40] Gen 298 - Mean fitness 0.785 - Best 0.8834 - PostVar 4.310 - Time 8.41
# datapoints:  82 / total:  250
# [03:14:50] Gen 299 - Mean fitness 0.798 - Best 0.8834 - PostVar 4.084 - Time 9.51
# datapoints:  109 / total:  250
# [03:15:01] Gen 300 - Mean fitness 0.789 - Best 0.8834 - PostVar 4.052 - Time 11.63
# datapoints:  141 / total:  250
# [03:15:13] Gen 301 - Mean fitness 0.773 - Best 0.8834 - PostVar 4.530 - Time 11.30
# datapoints:  167 / total:  250
# [03:15:23] Gen 302 - Mean fitness 0.764 - Best 0.8834 - PostVar 4.360 - Time 10.48
# datapoints:  120 / total:  250
# [03:15:35] Gen 303 - Mean fitness 0.781 - Best 0.8834 - PostVar 4.733 - Time 11.50
# datapoints:  124 / total:  250
# [03:15:45] Gen 304 - Mean fitness 0.780 - Best 0.8834 - PostVar 4.528 - Time 10.52
# datapoints:  113 / total:  250
# [03:15:56] Gen 305 - Mean fitness 0.787 - Best 0.8834 - PostVar 4.343 - Time 10.58
# datapoints:  125 / total:  250
# [03:16:07] Gen 306 - Mean fitness 0.779 - Best 0.8834 - PostVar 4.729 - Time 10.45
# datapoints:  116 / total:  250
# [03:16:21] Gen 307 - Mean fitness 0.786 - Best 0.8834 - PostVar 4.131 - Time 14.59
# datapoints:  95 / total:  250
# [03:16:41] Gen 308 - Mean fitness 0.794 - Best 0.8834 - PostVar 4
# [03:26:00] Gen 355 - Mean fitness 0.788 - Best 0.8842 - PostVar 4.245 - Time 12.71
# datapoints:  119 / total:  250
# [03:26:12] Gen 356 - Mean fitness 0.793 - Best 0.8842 - PostVar 4.030 - Time 11.50
# datapoints:  71 / total:  250
# [03:26:28] Gen 357 - Mean fitness 0.810 - Best 0.8842 - PostVar 4.277 - Time 15.53
# datapoints:  55 / total:  250
# [03:26:43] Gen 358 - Mean fitness 0.816 - Best 0.8842 - PostVar 4.334 - Time 15.77
# datapoints:  43 / total:  250
# [03:26:59] Gen 359 - Mean fitness 0.820 - Best 0.8842 - PostVar 4.622 - Time 15.15
# datapoints:  88 / total:  250
# [03:27:10] Gen 360 - Mean fitness 0.804 - Best 0.8842 - PostVar 4.472 - Time 11.28
# datapoints:  126 / total:  250
# [03:27:22] Gen 361 - Mean fitness 0.791 - Best 0.8842 - PostVar 4.379 - Time 12.41
# datapoints:  100 / total:  250
# [03:27:39] Gen 362 - Mean fitness 0.800 - Best 0.8842 - PostVar 4.246 - Time 16.37
# datapoints:  139 / total:  250
# [03:27:46] Gen 363 - Mean fitness 0.781 - Best 0.8842 - PostVar 4.307 - Time 7.48
# datapoints:  102 / total:  250
# [03:27:57] Gen 364 - Mean fitness 0.799 - Best 0.8842 - PostVar 4.267 - Time 10.41
# datapoints:  133 / total:  250
# [03:28:11] Gen 365 - Mean fitness 0.787 - Best 0.8842 - PostVar 4.434 - Time 13.96
# datapoints:  123 / total:  250
# [03:28:24] Gen 366 - Mean fitness 0.793 - Best 0.8842 - PostVar 4.203 - Time 13.47
# datapoints:  151 / total:  250
# [03:28:35] Gen 367 - Mean fitness 0.775 - Best 0.8842 - PostVar 4.408 - Time 10.81
# datapoints:  138 / total:  250
# [03:28:45] Gen 368 - Mean fitness 0.783 - Best 0.8842 - PostVar 4.358 - Time 10.07
# datapoints:  138 / total:  250
# [03:28:57] Gen 369 - Mean fitness 0.785 - Best 0.8842 - PostVar 4.248 - Time 10.99
# datapoints:  99 / total:  250
# [03:29:09] Gen 370 - Mean fitness 0.801 - Best 0.8842 - PostVar 4.141 - Time 12.66
# datapoints:  78 / total:  250
# [03:29:20] Gen 371 - Mean fitness 0.811 - Best 0.8842 - PostVar 4.245 - Time 11.15
# datapoints:  79 / total:  250
# [03:29:35] Gen 372 - Mean fitness 0.811 - Best 0.8842 - PostVar 4.425 - Time 14.41
# datapoints:  86 / total:  250
# [03:29:46] Gen 373 - Mean fitness 0.807 - Best 0.8842 - PostVar 4.480 - Time 10.54
# datapoints:  110 / total:  250
# [03:29:56] Gen 374 - Mean fitness 0.797 - Best 0.8842 - PostVar 4.559 - Time 10.66
# datapoints:  149 / total:  250
# [03:30:05] Gen 375 - Mean fitness 0.776 - Best 0.8842 - PostVar 4.193 - Time 8.97
# datapoints:  127 / total:  250
# [03:30:23] Gen 376 - Mean fitness 0.789 - Best 0.8842 - PostVar 4.403 - Time 17.41
# datapoints:  112 / total:  250
# [03:30:33] Gen 377 - Mean fitness 0.795 - Best 0.8842 - PostVar 4.326 - Time 10.07
# datapoints:  142 / total:  250
# [03:30:45] Gen 378 - Mean fitness 0.780 - Best 0.8842 - PostVar 4.588 - Time 12.43
# datapoints:  150 / total:  250
# [03:30:56] Gen 379 - Mean fitness 0.773 - Best 0.8842 - PostVar 4.483 - Time 10.42
# datapoints:  133 / total:  250
# [03:31:07] Gen 380 - Mean fitness 0.787 - Best 0.8842 - PostVar 4.397 - Time 10.97
# datapoints:  143 / total:  250
# [03:31:22] Gen 381 - Mean fitness 0.778 - Best 0.8842 - PostVar 4.412 - Time 14.75
# datapoints:  96 / total:  250
# [03:31:33] Gen 382 - Mean fitness 0.803 - Best 0.8842 - PostVar 4.213 - Time 11.44
# datapoints:  129 / total:  250
# [03:31:44] Gen 383 - Mean fitness 0.788 - Best 0.8842 - PostVar 4.184 - Time 10.46
# datapoints:  48 / total:  250
# [03:31:57] Gen 384 - Mean fitness 0.820 - Best 0.9229 - PostVar 4.273 - Time 13.29
# datapoints:  46 / total:  250
# [03:32:14] Gen 385 - Mean fitness 0.824 - Best 0.9229 - PostVar 4.417 - Time 17.05
# datapoints:  73 / total:  250
# [03:32:29] Gen 386 - Mean fitness 0.812 - Best 0.9229 - PostVar 4.201 - Time 14.98
# datapoints:  84 / total:  250
# [03:32:45] Gen 387 - Mean fitness 0.808 - Best 0.9229 - PostVar 4.476 - Time 15.33
# datapoints:  110 / total:  250
# [03:32:56] Gen 388 - Mean fitness 0.799 - Best 0.9229 - PostVar 4.169 - Time 10.80
# datapoints:  124 / total:  250
# [03:33:09] Gen 389 - Mean fitness 0.793 - Best 0.9229 - PostVar 4.238 - Time 13.69
# datapoints:  94 / total:  250
# [03:33:23] Gen 390 - Mean fitness 0.804 - Best 0.9229 - PostVar 4.644 - Time 13.65
# datapoints:  54 / total:  250
# [03:33:36] Gen 391 - Mean fitness 0.820 - Best 0.9229 - PostVar 4.657 - Time 12.70
# datapoints:  77 / total:  250
# [03:33:48] Gen 392 - Mean fitness 0.812 - Best 0.9229 - PostVar 4.301 - Time 11.62
# datapoints:  51 / total:  250
# [03:34:05] Gen 393 - Mean fitness 0.822 - Best 0.9229 - PostVar 4.230 - Time 17.64
# datapoints:  42 / total:  250
# [03:34:17] Gen 394 - Mean fitness 0.831 - Best 0.9229 - PostVar 4.538 - Time 11.38
# datapoints:  83 / total:  250
# [03:34:31] Gen 395 - Mean fitness 0.811 - Best 0.9229 - PostVar 4.014 - Time 14.41
# datapoints:  81 / total:  250
# [03:34:45] Gen 396 - Mean fitness 0.813 - Best 0.9229 - PostVar 4.150 - Time 13.79
# datapoints:  54 / total:  250
# [03:35:00] Gen 397 - Mean fitness 0.824 - Best 0.9229 - PostVar 4.678 - Time 14.75
# datapoints:  94 / total:  250
# [03:35:13] Gen 398 - Mean fitness 0.808 - Best 0.9229 - PostVar 4.550 - Time 12.73
# datapoints:  73 / total:  250
# [03:35:24] Gen 399 - Mean fitness 0.815 - Best 0.9229 - PostVar 4.517 - Time 10.72
# datapoints:  89 / total:  250
# [03:35:34] Gen 400 - Mean fitness 0.810 - Best 0.9229 - PostVar 4.548 - Time 10.13
# datapoints:  118 / total:  250
# [03:35:46] Gen 401 - Mean fitness 0.799 - Best 0.9229 - PostVar 4.208 - Time 11.86
# datapoints:  111 / total:  250
# [03:35:58] Gen 402 - Mean fitness 0.801 - Best 0.9229 - PostVar 4.167 - Time 12.61
# datapoints:  102 / total:  250
# [03:36:12] Gen 403 - Mean fitness 0.804 - Best 0.9229 - PostVar 4.545 - Time 13.47
# datapoints:  106 / total:  250
# [03:36:23] Gen 404 - Mean fitness 0.803 - Best 0.9229 - PostVar 4.024 - Time 10.75
# datapoints:  124 / total:  250
# [03:36:38] Gen 405 - Mean fitness 0.796 - Best 0.9229 - PostVar 4.463 - Time 15.31
# datapoints:  91 / total:  250
# [03:36:55] Gen 406 - Mean fitness 0.810 - Best 0.9229 - PostVar 4.563 - Time 16.70
# datapoints:  77 / total:  250
# [03:37:08] Gen 407 - Mean fitness 0.814 - Best 0.9229 - PostVar 4.300 - Time 12.87
# datapoints:  98 / total:  250
# [03:37:26] Gen 408 - Mean fitness 0.807 - Best 0.9229 - PostVar 4.402 - Time 17.52
# datapoints:  86 / total:  250
# [03:37:37] Gen 409 - Mean fitness 0.812 - Best 0.9229 - PostVar 4.098 - Time 11.34
# datapoints:  115 / total:  250
# [03:37:44] Gen 410 - Mean fitness 0.800 - Best 0.9229 - PostVar 4.381 - Time 7.26
# datapoints:  150 / total:  250
# [03:37:54] Gen 411 - Mean fitness 0.787 - Best 0.9229 - PostVar 4.227 - Time 9.51
# datapoints:  173 / total:  250
# [03:38:03] Gen 412 - Mean fitness 0.769 - Best 0.9229 - PostVar 4.139 - Time 9.26
# datapoints:  125 / total:  250
# [03:38:20] Gen 413 - Mean fitness 0.797 - Best 0.9229 - PostVar 4.724 - Time 16.90
# datapoints:  117 / total:  250
# [03:38:31] Gen 414 - Mean fitness 0.800 - Best 0.9229 - PostVar 4.078 - Time 10.91
# datapoints:  89 / total:  250
# [03:38:48] Gen 415 - Mean fitness 0.811 - Best 0.9229 - PostVar 4.199 - Time 17.07
# datapoints:  126 / total:  250
# [03:38:59] Gen 416 - Mean fitness 0.798 - Best 0.9229 - PostVar 3.787 - Time 10.97
# datapoints:  141 / total:  250
# [03:39:08] Gen 417 - Mean fitness 0.791 - Best 0.9229 - PostVar 4.288 - Time 8.58
# datapoints:  185 / total:  250
# [03:39:16] Gen 418 - Mean fitness 0.765 - Best 0.9229 - PostVar 4.655 - Time 8.33
# datapoints:  108 / total:  250
# [03:39:34] Gen 419 - Mean fitness 0.804 - Best 0.9229 - PostVar 4.033 - Time 17.32
# datapoints:  106 / total:  250
# [03:39:43] Gen 420 - Mean fitness 0.804 - Best 0.9229 - PostVar 4.337 - Time 9.58
# datapoints:  75 / total:  250
# [03:39:57] Gen 421 - Mean fitness 0.817 - Best 0.9229 - PostVar 4.220 - Time 13.30
# datapoints:  87 / total:  250
# [03:40:11] Gen 422 - Mean fitness 0.814 - Best 0.9229 - PostVar 4.586 - Time 14.17
# datapoints:  169 / total:  250
# [03:40:21] Gen 423 - Mean fitness 0.775 - Best 0.9229 - PostVar 4.176 - Time 10.12
# datapoints:  150 / total:  250
# [03:40:29] Gen 424 - Mean fitness 0.788 - Best 0.9229 - PostVar 4.297 - Time 7.79
# datapoints:  93 / total:  250
# ...
# datapoints:  76 / total:  250
# [04:21:52] Gen 613 - Mean fitness 0.850 - Best 0.9429 - PostVar 3.769 - Time 14.41
# datapoints:  74 / total:  250
# [04:22:03] Gen 614 - Mean fitness 0.850 - Best 0.9429 - PostVar 3.939 - Time 11.40
# datapoints:  112 / total:  250
# [04:22:20] Gen 615 - Mean fitness 0.837 - Best 0.9429 - PostVar 3.653 - Time 16.81
# datapoints:  62 / total:  250
# [04:22:37] Gen 616 - Mean fitness 0.855 - Best 0.9429 - PostVar 4.228 - Time 17.07
# datapoints:  87 / total:  250
# [04:22:54] Gen 617 - Mean fitness 0.845 - Best 0.9429 - PostVar 3.962 - Time 16.39
# datapoints:  103 / total:  250
# [04:23:14] Gen 618 - Mean fitness 0.840 - Best 0.9429 - PostVar 4.069 - Time 19.78
# datapoints:  44 / total:  250
# [04:23:29] Gen 619 - Mean fitness 0.863 - Best 0.9429 - PostVar 4.144 - Time 15.74
# datapoints:  29 / total:  250
# [04:23:46] Gen 620 - Mean fitness 0.871 - Best 0.9429 - PostVar 4.773 - Time 16.05
# datapoints:  123 / total:  250
# [04:23:58] Gen 621 - Mean fitness 0.835 - Best 0.9429 - PostVar 3.751 - Time 12.07
# datapoints:  167 / total:  250
# [04:24:14] Gen 622 - Mean fitness 0.812 - Best 0.9429 - PostVar 3.696 - Time 16.08
# datapoints:  119 / total:  250
# [04:24:28] Gen 623 - Mean fitness 0.836 - Best 0.9429 - PostVar 4.083 - Time 14.46
# datapoints:  133 / total:  250
# [04:24:38] Gen 624 - Mean fitness 0.826 - Best 0.9429 - PostVar 3.734 - Time 10.00
# datapoints:  137 / total:  250
# [04:24:54] Gen 625 - Mean fitness 0.824 - Best 0.9429 - PostVar 3.698 - Time 15.84
# datapoints:  130 / total:  250
# [04:25:10] Gen 626 - Mean fitness 0.829 - Best 0.9429 - PostVar 3.886 - Time 15.21
# datapoints:  101 / total:  250
# [04:25:23] Gen 627 - Mean fitness 0.841 - Best 0.9429 - PostVar 4.293 - Time 13.09
# datapoints:  128 / total:  250
# [04:25:39] Gen 628 - Mean fitness 0.831 - Best 0.9429 - PostVar 3.636 - Time 16.13
# datapoints:  161 / total:  250
# [04:25:50] Gen 629 - Mean fitness 0.814 - Best 0.9429 - PostVar 3.874 - Time 10.56
# datapoints:  167 / total:  250
# [04:25:59] Gen 630 - Mean fitness 0.811 - Best 0.9429 - PostVar 3.684 - Time 9.21
# datapoints:  109 / total:  250
# [04:26:17] Gen 631 - Mean fitness 0.839 - Best 0.9429 - PostVar 3.562 - Time 17.70
# datapoints:  83 / total:  250
# [04:26:40] Gen 632 - Mean fitness 0.849 - Best 0.9429 - PostVar 3.916 - Time 22.85
# datapoints:  92 / total:  250
# [04:26:49] Gen 633 - Mean fitness 0.845 - Best 0.9429 - PostVar 4.079 - Time 9.48
# datapoints:  69 / total:  250
# [04:27:04] Gen 634 - Mean fitness 0.855 - Best 0.9429 - PostVar 3.810 - Time 15.00
# datapoints:  73 / total:  250
# [04:27:16] Gen 635 - Mean fitness 0.854 - Best 0.9429 - PostVar 4.020 - Time 12.10
# datapoints:  70 / total:  250
# [04:27:32] Gen 636 - Mean fitness 0.855 - Best 0.9429 - PostVar 3.854 - Time 15.86
# datapoints:  125 / total:  250
# [04:27:43] Gen 637 - Mean fitness 0.832 - Best 0.9429 - PostVar 4.012 - Time 11.16
# datapoints:  89 / total:  250
# [04:27:55] Gen 638 - Mean fitness 0.847 - Best 0.9429 - PostVar 3.924 - Time 11.31
# datapoints:  76 / total:  250
# [04:28:13] Gen 639 - Mean fitness 0.852 - Best 0.9429 - PostVar 3.754 - Time 17.70
# datapoints:  115 / total:  250
# [04:28:27] Gen 640 - Mean fitness 0.838 - Best 0.9429 - PostVar 4.050 - Time 13.83
# datapoints:  149 / total:  250
# [04:28:35] Gen 641 - Mean fitness 0.821 - Best 0.9429 - PostVar 4.095 - Time 8.80
# datapoints:  135 / total:  250
# [04:28:50] Gen 642 - Mean fitness 0.825 - Best 0.9429 - PostVar 3.787 - Time 14.84
# datapoints:  124 / total:  250
# [04:29:07] Gen 643 - Mean fitness 0.833 - Best 0.9429 - PostVar 3.755 - Time 16.94
# datapoints:  125 / total:  250
# [04:29:23] Gen 644 - Mean fitness 0.834 - Best 0.9429 - PostVar 3.692 - Time 15.18
# datapoints:  132 / total:  250
# [04:29:37] Gen 645 - Mean fitness 0.829 - Best 0.9429 - PostVar 3.820 - Time 14.13
# datapoints:  134 / total:  250
# [04:29:47] Gen 646 - Mean fitness 0.828 - Best 0.9429 - PostVar 3.757 - Time 9.81
# datapoints:  63 / total:  250
# [04:30:02] Gen 647 - Mean fitness 0.858 - Best 0.9429 - PostVar 3.594 - Time 15.53
# datapoints:  44 / total:  250
# [04:30:16] Gen 648 - Mean fitness 0.865 - Best 0.9429 - PostVar 4.049 - Time 14.17
# datapoints:  41 / total:  250
# [04:30:30] Gen 649 - Mean fitness 0.867 - Best 0.9429 - PostVar 3.640 - Time 13.16
# datapoints:  74 / total:  250
# [04:30:42] Gen 650 - Mean fitness 0.856 - Best 0.9429 - PostVar 3.889 - Time 11.97
# datapoints:  121 / total:  250
# [04:30:53] Gen 651 - Mean fitness 0.839 - Best 0.9429 - PostVar 4.001 - Time 11.45
# datapoints:  55 / total:  250
# [04:31:07] Gen 652 - Mean fitness 0.862 - Best 0.9429 - PostVar 4.090 - Time 14.00
# datapoints:  138 / total:  250
# [04:31:18] Gen 653 - Mean fitness 0.830 - Best 0.9429 - PostVar 3.946 - Time 11.00
# datapoints:  135 / total:  250
# [04:31:38] Gen 654 - Mean fitness 0.832 - Best 0.9429 - PostVar 3.986 - Time 19.30
# datapoints:  150 / total:  250
# [04:31:52] Gen 655 - Mean fitness 0.823 - Best 0.9429 - PostVar 3.649 - Time 14.47
# datapoints:  130 / total:  250
# [04:32:04] Gen 656 - Mean fitness 0.834 - Best 0.9429 - PostVar 3.532 - Time 11.89
# datapoints:  135 / total:  250
# [04:32:16] Gen 657 - Mean fitness 0.831 - Best 0.9429 - PostVar 3.618 - Time 11.32
# datapoints:  163 / total:  250
# [04:32:26] Gen 658 - Mean fitness 0.817 - Best 0.9429 - PostVar 3.569 - Time 10.37
# datapoints:  173 / total:  250
# [04:32:38] Gen 659 - Mean fitness 0.811 - Best 0.9429 - PostVar 3.856 - Time 11.92
# datapoints:  130 / total:  250
# [04:32:53] Gen 660 - Mean fitness 0.833 - Best 0.9429 - PostVar 3.686 - Time 15.08
# datapoints:  133 / total:  250
# [04:33:10] Gen 661 - Mean fitness 0.831 - Best 0.9429 - PostVar 4.042 - Time 16.63
# datapoints:  130 / total:  250
# [04:33:20] Gen 662 - Mean fitness 0.833 - Best 0.9429 - PostVar 3.991 - Time 9.79
# datapoints:  102 / total:  250
# [04:33:32] Gen 663 - Mean fitness 0.842 - Best 0.9429 - PostVar 4.004 - Time 12.25
# datapoints:  86 / total:  250
# [04:33:47] Gen 664 - Mean fitness 0.849 - Best 0.9429 - PostVar 4.255 - Time 14.70
# datapoints:  77 / total:  250
# [04:34:07] Gen 665 - Mean fitness 0.854 - Best 0.9429 - PostVar 3.843 - Time 20.15
# datapoints:  88 / total:  250
# [04:34:22] Gen 666 - Mean fitness 0.848 - Best 0.9429 - PostVar 3.938 - Time 14.69
# datapoints:  85 / total:  250
# [04:34:38] Gen 667 - Mean fitness 0.848 - Best 0.9429 - PostVar 3.736 - Time 15.88
# datapoints:  134 / total:  250
# [04:34:50] Gen 668 - Mean fitness 0.830 - Best 0.9429 - PostVar 3.867 - Time 12.19
# datapoints:  94 / total:  250
# [04:35:07] Gen 669 - Mean fitness 0.845 - Best 0.9429 - PostVar 3.884 - Time 16.70
# datapoints:  160 / total:  250
# [04:35:16] Gen 670 - Mean fitness 0.815 - Best 0.9429 - PostVar 3.725 - Time 8.93
# datapoints:  159 / total:  250
# [04:35:27] Gen 671 - Mean fitness 0.816 - Best 0.9429 - PostVar 4.069 - Time 11.38
# datapoints:  148 / total:  250
# [04:35:42] Gen 672 - Mean fitness 0.821 - Best 0.9429 - PostVar 3.685 - Time 14.77
# datapoints:  149 / total:  250
# [04:35:55] Gen 673 - Mean fitness 0.822 - Best 0.9429 - PostVar 3.766 - Time 12.71
# datapoints:  152 / total:  250
# [04:36:10] Gen 674 - Mean fitness 0.819 - Best 0.9429 - PostVar 3.920 - Time 14.83
# datapoints:  180 / total:  250
# [04:36:21] Gen 675 - Mean fitness 0.808 - Best 0.9429 - PostVar 3.290 - Time 11.42
# datapoints:  157 / total:  250
# [04:36:38] Gen 676 - Mean fitness 0.817 - Best 0.9429 - PostVar 3.840 - Time 16.22
# datapoints:  127 / total:  250
# [04:36:48] Gen 677 - Mean fitness 0.835 - Best 0.9429 - PostVar 3.592 - Time 10.37
# datapoints:  127 / total:  250
# [04:36:59] Gen 678 - Mean fitness 0.835 - Best 0.9429 - PostVar 3.980 - Time 11.12
# datapoints:  105 / total:  250
# [04:37:17] Gen 679 - Mean fitness 0.841 - Best 0.9429 - PostVar 3.869 - Time 17.72
# datapoints:  141 / total:  250
# [04:37:31] Gen 680 - Mean fitness 0.829 - Best 0.9429 - PostVar 4.162 - Time 13.85
# datapoints:  135 / total:  250
# [04:37:47] Gen 681 - Mean fitness 0.830 - Best 0.9429 - PostVar 3.828 - Time 16.01
# datapoints:  160 / total:  250
# [04:37:57] Gen 682 - Mean fitness 0.817 - Best 0.9429 - PostVar 3.670 - Time 9.85
# datapoints:  167 / total:  250
# [04:38:08] Gen 683 - Mean fitness 0.814 - Best 0.9429 - PostVar 3.752 - Time 11.12
# datapoints:  175 / total:  250
# [04:38:19] Gen 684 - Mean fitness 0.811 - Best 0.9429 - PostVar 3.631 - Time 11.13
# datapoints:  176 / total:  250
# [04:38:30] Gen 685 - Mean fitness 0.808 - Best 0.9429 - PostVar 3.780 - Time 10.45
# datapoints:  140 / total:  250
# [04:38:42] Gen 686 - Mean fitness 0.827 - Best 0.9429 - PostVar 3.666 - Time 12.26
# datapoints:  194 / total:  250
# [04:38:54] Gen 687 - Mean fitness 0.802 - Best 0.9429 - PostVar 4.019 - Time 12.17
# datapoints:  165 / total:  250
# [04:39:11] Gen 688 - Mean fitness 0.813 - Best 0.9429 - PostVar 4.065 - Time 16.76
# datapoints:  162 / total:  250
# [04:39:23] Gen 689 - Mean fitness 0.815 - Best 0.9429 - PostVar 3.758 - Time 11.55
# datapoints:  84 / total:  250
# [04:39:38] Gen 690 - Mean fitness 0.850 - Best 0.9429 - PostVar 3.733 - Time 15.14
# datapoints:  55 / total:  250
# [04:39:54] Gen 691 - Mean fitness 0.864 - Best 0.9429 - PostVar 3.781 - Time 16.20
# datapoints:  50 / total:  250
# [04:40:06] Gen 692 - Mean fitness 0.866 - Best 0.9429 - PostVar 3.961 - Time 11.38
# datapoints:  85 / total:  250
# [04:40:17] Gen 693 - Mean fitness 0.850 - Best 0.9429 - PostVar 3.841 - Time 11.03
# datapoints:  106 / total:  250
# [04:40:33] Gen 694 - Mean fitness 0.841 - Best 0.9429 - PostVar 3.903 - Time 16.10
# datapoints:  148 / total:  250
# [04:40:46] Gen 695 - Mean fitness 0.823 - Best 0.9429 - PostVar 3.938 - Time 12.04
# datapoints:  143 / total:  250
# [04:41:04] Gen 696 - Mean fitness 0.826 - Best 0.9429 - PostVar 3.528 - Time 17.46
# datapoints:  118 / total:  250
# [04:41:21] Gen 697 - Mean fitness 0.837 - Best 0.9429 - PostVar 3.488 - Time 17.21
# datapoints:  118 / total:  250
# [04:41:39] Gen 698 - Mean fitness 0.837 - Best 0.9429 - PostVar 3.700 - Time 18.13
# datapoints:  147 / total:  250
# [04:41:56] Gen 699 - Mean fitness 0.824 - Best 0.9429 - PostVar 3.801 - Time 17.21
# datapoints:  173 / total:  250
# [04:42:06] Gen 700 - Mean fitness 0.811 - Best 0.9429 - PostVar 4.005 - Time 9.13
# datapoints:  155 / total:  250
# [04:42:22] Gen 701 - Mean fitness 0.820 - Best 0.9429 - PostVar 3.782 - Time 16.01
# datapoints:  92 / total:  250
# [04:42:43] Gen 702 - Mean fitness 0.847 - Best 0.9429 - PostVar 4.104 - Time 21.14
# datapoints:  141 / total:  250
# [04:42:55] Gen 703 - Mean fitness 0.827 - Best 0.9429 - PostVar 3.472 - Time 12.31
# datapoints:  149 / total:  250
# [04:43:10] Gen 704 - Mean fitness 0.823 - Best 0.9429 - PostVar 4.004 - Time 14.83
# datapoints:  92 / total:  250
# [04:43:33] Gen 705 - Mean fitness 0.849 - Best 0.9429 - PostVar 3.733 - Time 22.23
# datapoints:  136 / total:  250
# [04:43:48] Gen 706 - Mean fitness 0.830 - Best 0.9429 - PostVar 3.819 - Time 14.93
# datapoints:  156 / total:  250
# [04:44:02] Gen 707 - Mean fitness 0.820 - Best 0.9429 - PostVar 3.814 - Time 14.58
# datapoints:  117 / total:  250
# [04:44:22] Gen 708 - Mean fitness 0.838 - Best 0.9429 - PostVar 3.471 - Time 19.41
# datapoints:  141 / total:  250
# [04:44:37] Gen 709 - Mean fitness 0.829 - Best 0.9429 - PostVar 4.040 - Time 14.91
# datapoints:  175 / total:  250
# [04:44:46] Gen 710 - Mean fitness 0.811 - Best 0.9429 - PostVar 3.536 - Time 9.60
# datapoints:  192 / total:  250
# [04:44:59] Gen 711 - Mean fitness 0.804 - Best 0.9429 - PostVar 4.087 - Time 12.76
# datapoints:  175 / total:  250
# [04:45:10] Gen 712 - Mean fitness 0.810 - Best 0.9429 - PostVar 3.805 - Time 11.09
# datapoints:  99 / total:  250
# [04:45:28] Gen 713 - Mean fitness 0.845 - Best 0.9429 - PostVar 3.782 - Time 17.90
# datapoints:  141 / total:  250
# [04:45:41] Gen 714 - Mean fitness 0.828 - Best 0.9429 - PostVar 3.539 - Time 12.51
# datapoints:  115 / total:  250
# [04:45:58] Gen 715 - Mean fitness 0.838 - Best 0.9429 - PostVar 3.688 - Time 17.51
# datapoints:  103 / total:  250
# [04:46:16] Gen 716 - Mean fitness 0.843 - Best 0.9429 - PostVar 3.440 - Time 17.89
# datapoints:  139 / total:  250
# [04:46:29] Gen 717 - Mean fitness 0.828 - Best 0.9429 - PostVar 3.652 - Time 12.64
# datapoints:  104 / total:  250
# [04:46:47] Gen 718 - Mean fitness 0.843 - Best 0.9429 - PostVar 3.833 - Time 17.83
# datapoints:  74 / total:  250
# [04:47:08] Gen 719 - Mean fitness 0.859 - Best 0.9429 - PostVar 3.621 - Time 20.62
# datapoints:  67 / total:  250
# [04:47:24] Gen 720 - Mean fitness 0.863 - Best 0.9429 - PostVar 3.621 - Time 15.94
# datapoints:  144 / total:  250
# [04:47:35] Gen 721 - Mean fitness 0.827 - Best 0.9429 - PostVar 3.497 - Time 11.26
# datapoints:  123 / total:  250
# [04:47:55] Gen 722 - Mean fitness 0.837 - Best 0.9429 - PostVar 3.852 - Time 19.59
# datapoints:  102 / total:  250
# [04:48:12] Gen 723 - Mean fitness 0.845 - Best 0.9429 - PostVar 3.868 - Time 16.92
# datapoints:  152 / total:  250
# [04:48:26] Gen 724 - Mean fitness 0.824 - Best 0.9429 - PostVar 3.773 - Time 13.79
# datapoints:  156 / total:  250
# [04:48:45] Gen 725 - Mean fitness 0.822 - Best 0.9429 - PostVar 4.148 - Time 19.02
# datapoints:  119 / total:  250
# [04:49:00] Gen 726 - Mean fitness 0.839 - Best 0.9429 - PostVar 3.795 - Time 14.53
# datapoints:  167 / total:  250
# [04:49:10] Gen 727 - Mean fitness 0.814 - Best 0.9429 - PostVar 3.857 - Time 10.67
# datapoints:  146 / total:  250
# [04:49:20] Gen 728 - Mean fitness 0.828 - Best 0.9429 - PostVar 3.625 - Time 9.15
# datapoints:  157 / total:  250
# [04:49:28] Gen 729 - Mean fitness 0.819 - Best 0.9429 - PostVar 3.982 - Time 8.03
# datapoints:  150 / total:  250
# [04:49:38] Gen 730 - Mean fitness 0.825 - Best 0.9429 - PostVar 3.868 - Time 10.41
# datapoints:  162 / total:  250
# [04:49:52] Gen 731 - Mean fitness 0.817 - Best 0.9429 - PostVar 3.710 - Time 13.89
# datapoints:  208 / total:  250
# [04:50:04] Gen 732 - Mean fitness 0.791 - Best 0.9429 - PostVar 3.785 - Time 11.63
# datapoints:  149 / total:  250
# [04:50:14] Gen 733 - Mean fitness 0.824 - Best 0.9429 - PostVar 3.560 - Time 10.51
# datapoints:  97 / total:  250
# [04:50:30] Gen 734 - Mean fitness 0.849 - Best 0.9429 - PostVar 3.896 - Time 15.80
# datapoints:  106 / total:  250
# [04:50:46] Gen 735 - Mean fitness 0.844 - Best 0.9429 - PostVar 3.885 - Time 15.48
# datapoints:  137 / total:  250
# [04:50:55] Gen 736 - Mean fitness 0.832 - Best 0.9429 - PostVar 3.612 - Time 8.97
# datapoints:  131 / total:  250
# [04:51:04] Gen 737 - Mean fitness 0.834 - Best 0.9429 - PostVar 3.595 - Time 9.26
# datapoints:  92 / total:  250
# [04:51:20] Gen 738 - Mean fitness 0.852 - Best 0.9429 - PostVar 3.809 - Time 15.50
# datapoints:  105 / total:  250
# [04:51:32] Gen 739 - Mean fitness 0.843 - Best 0.9429 - PostVar 3.842 - Time 11.75
# datapoints:  106 / total:  250
# [04:51:48] Gen 740 - Mean fitness 0.843 - Best 0.9429 - PostVar 3.832 - Time 16.71
# datapoints:  155 / total:  250
# [04:52:02] Gen 741 - Mean fitness 0.819 - Best 0.9429 - PostVar 3.722 - Time 13.54
# datapoints:  133 / total:  250
# [04:52:12] Gen 742 - Mean fitness 0.833 - Best 0.9429 - PostVar 3.741 - Time 10.39
# datapoints:  144 / total:  250
# [04:52:23] Gen 743 - Mean fitness 0.828 - Best 0.9429 - PostVar 4.032 - Time 9.99
# datapoints:  120 / total:  250
# [04:52:42] Gen 744 - Mean fitness 0.837 - Best 0.9429 - PostVar 3.871 - Time 19.72
# datapoints:  142 / total:  250
# [04:52:56] Gen 745 - Mean fitness 0.828 - Best 0.9429 - PostVar 3.792 - Time 13.54
# datapoints:  144 / total:  250
# [04:53:08] Gen 746 - Mean fitness 0.827 - Best 0.9429 - PostVar 3.874 - Time 12.27
# datapoints:  155 / total:  250
# [04:53:22] Gen 747 - Mean fitness 0.820 - Best 0.9429 - PostVar 3.611 - Time 13.30
# datapoints:  147 / total:  250
# [04:53:37] Gen 748 - Mean fitness 0.825 - Best 0.9429 - PostVar 3.638 - Time 15.11
# datapoints:  182 / total:  250
# [04:53:46] Gen 749 - Mean fitness 0.808 - Best 0.9429 - PostVar 3.794 - Time 8.79
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman

# %%
pd.DataFrame(hist).sort_values('test_reward', ascending=False).head()
# Out:
#       gen                                                arc  test_reward  \
# 1032  516  [conv1d:{'kernel_size': 1, 'filters': 1, 'SOUR...     0.942934
# 881   440  [conv1d:{'kernel_size': 1, 'filters': 1, 'SOUR...     0.938724
# 1239  619  [conv1d:{'kernel_size': 1, 'filters': 1, 'SOUR...     0.934716
# 1438  719  [conv1d:{'kernel_size': 1, 'filters': 1, 'SOUR...     0.930050
# 769   384  [conv1d:{'kernel_size': 1, 'filters': 1, 'SOUR...     0.922920
#
#      rate_df
# 1032    None
# 881     None
# 1239    None
# 1438    None
# 769     None

# %%
print("\n".join([str(x) 
                 for x in pd.DataFrame(hist).
                 sort_values('test_reward', ascending=False).
                 head(1)['arc'].values[0]]))
# Out:
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '0', 'TARGET': '1', 'EDGE': 1, 'RANGE_ST': 5, 'RANGE_D': 5}
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '1', 'TARGET': '0', 'EDGE': 1, 'RANGE_ST': 10, 'RANGE_D': 14}
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '1', 'TARGET': '2', 'EDGE': 1, 'RANGE_ST': 15, 'RANGE_D': 10}
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '2', 'TARGET': '1', 'EDGE': 1, 'RANGE_ST': 20, 'RANGE_D': 5}
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '2', 'TARGET': '3', 'EDGE': 1, 'RANGE_ST': 25, 'RANGE_D': 4}
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '3', 'TARGET': '2', 'EDGE': 1, 'RANGE_ST': 30, 'RANGE_D': 9}
# conv1d:{'kernel_size': 1, 'filters': 1, 'SOURCE': '3', 'TARGET': '0', 'EDGE': 1, 'RANGE_ST': 35, 'RANGE_D': 5, 'CONTRIB': 1}

# %%
a = pd.DataFrame(hist)
a['arc'] = ['|'.join([f"{x.Layer_attributes['RANGE_ST']}-{x.Layer_attributes['RANGE_ST']+x.Layer_attributes['RANGE_D']}" for x in entry]) for entry in a['arc']]
a.drop(columns=['rate_df'], inplace=True)
a.to_csv(os.path.join(wd,"train_history.tsv"), sep="\t", index=False)

# %%
# %matplotlib inline

ax = stat_df.plot.line(x='Generation', y=['GenAvg', 'Best'])
ax.set_ylabel("Reward (Pearson correlation)")
ax.set_xlabel("Generation")
#plt.savefig("reward_vs_time.png")
# Out:
# Text(0.5, 0, 'Generation')

# %%
# ground truth
plot_gt = True
with open(param_fp, "r") as f:
    gt_model_params = yaml.load(f, Loader=yaml.Loader)
gt_model_params = modelParams_to_modelSpace(gt_model_params)
gt_rates = [k for k in gt_model_params['Rates']]

# %%
# START SITE
fig, axs_ = plt.subplots(3,3, figsize=(15,15))
axs = [axs_[i][j] for i in range(len(axs_)) for j in range(len(axs_[i]))]
for k in controller.model_space_probs:
    if k[-1] == 'RANGE_ST':
        try:
            d = controller.model_space_probs[k].sample(size=1000)
        except:
            continue
        ax = axs[k[0]]
        sns.distplot(d, label="Post", ax=ax)
        sns.distplot(controller.model_space_probs[k].prior_dist, label="Prior", ax=ax)
        if plot_gt:
            ax.axvline(gt_rates[k[0]]['RANGE_ST'], ls='--', color='black')
            ax.set_title(
                f'Rate ID{str(k[0])} = {gt_rates[k[0]]["name"]}\n'
                f'Ground truth={gt_rates[k[0]]["RANGE_ST"]}\nPosterior mode {str(ss.mode(d).mode)}')
        else:
            ax.set_title(
                f'Rate ID{str(k[0])} = {gt_rates[k[0]]["name"]}\n'
                f'Posterior mode {str(ss.mode(d).mode)}')
            

        #_ = ax.set_xlim(0,50)

fig.suptitle('range start')
fig.tight_layout()
#fig.savefig("range_st.png")

# %%
# CONV RANGE
fig, axs_ = plt.subplots(3,3, figsize=(15,15))
axs = [axs_[i][j] for i in range(len(axs_)) for j in range(len(axs_[i]))]
for k in controller.model_space_probs:
    if k[-1] == 'RANGE_D':
        d = controller.model_space_probs[k].sample(size=1000)
        ax = axs[k[0]]
        sns.distplot(d, ax=ax)
        sns.distplot(controller.model_space_probs[k].prior_dist, label="Prior", ax=ax)
        if plot_gt:
            ax.axvline(gt_rates[k[0]]['RANGE_D'], ls='--', color='black')
            ax.set_title(
                f'Rate ID{str(k[0])} = {gt_rates[k[0]]["name"]}\n'
                f'Ground truth={gt_rates[k[0]]["RANGE_D"]}\nPosterior mode {str(ss.mode(d).mode)}')
        else:
            ax.set_title(
                f'Rate ID{str(k[0])} = {gt_rates[k[0]]["name"]}\n'
                f'Posterior mode {str(ss.mode(d).mode)}')

fig.suptitle('range length')
fig.tight_layout()
#fig.savefig("range_d.png")

# %%
from src.neural_network_builder import KineticEigenModelBuilder, KineticNeuralNetworkBuilder
tf.compat.v1.reset_default_graph()
tf.compat.v1.experimental.output_all_intermediates(True)
sess = tf.compat.v1.Session()
mb = reload_from_dir(
    wd=wd, 
    manager_kwargs=manager_kwargs,
    sess=sess,
    model_fn=KineticNeuralNetworkBuilder)
model = mb.model
# Out:
# loaded searched model

# %%
[str(x.__dict__) for x in mb.kinn.rates]
# Out:
# ["{'name': 'k_01', 'state_list': ['0', '1'], 'input_range': [5, 10], 'kernel_size': 1, 'scatter_nd': [((0, 0), -1), ((1, 0), 1)], 'filters': 1, 'SOURCE': '0', 'TARGET': '1', 'EDGE': 1, 'RANGE_ST': 5, 'RANGE_D': 5, 'template': None, 'mat': None}",
#  "{'name': 'k_10', 'state_list': ['1', '0'], 'input_range': [10, 24], 'kernel_size': 1, 'scatter_nd': [((1, 1), -1), ((0, 1), 1)], 'filters': 1, 'SOURCE': '1', 'TARGET': '0', 'EDGE': 1, 'RANGE_ST': 10, 'RANGE_D': 14, 'template': None, 'mat': None}",
#  "{'name': 'k_12', 'state_list': ['1', '2'], 'input_range': [15, 25], 'kernel_size': 1, 'scatter_nd': [((1, 1), -1), ((2, 1), 1)], 'filters': 1, 'SOURCE': '1', 'TARGET': '2', 'EDGE': 1, 'RANGE_ST': 15, 'RANGE_D': 10, 'template': None, 'mat': None}",
#  "{'name': 'k_21', 'state_list': ['2', '1'], 'input_range': [20, 25], 'kernel_size': 1, 'scatter_nd': [((2, 2), -1), ((1, 2), 1)], 'filters': 1, 'SOURCE': '2', 'TARGET': '1', 'EDGE': 1, 'RANGE_ST': 20, 'RANGE_D': 5, 'template': None, 'mat': None}",
#  "{'name': 'k_23', 'state_list': ['2', '3'], 'input_range': [25, 29], 'kernel_size': 1, 'scatter_nd': [((2, 2), -1), ((3, 2), 1)], 'filters': 1, 'SOURCE': '2', 'TARGET': '3', 'EDGE': 1, 'RANGE_ST': 25, 'RANGE_D': 4, 'template': None, 'mat': None}",
#  "{'name': 'k_32', 'state_list': ['3', '2'], 'input_range': [30, 39], 'kernel_size': 1, 'scatter_nd': [((3, 3), -1), ((2, 3), 1)], 'filters': 1, 'SOURCE': '3', 'TARGET': '2', 'EDGE': 1, 'RANGE_ST': 30, 'RANGE_D': 9, 'template': None, 'mat': None}",
#  "{'name': 'k_30', 'state_list': ['3', '0'], 'input_range': [35, 40], 'kernel_size': 1, 'scatter_nd': [((3, 3), -1), ((0, 3), 1)], 'filters': 1, 'SOURCE': '3', 'TARGET': '0', 'EDGE': 1, 'RANGE_ST': 35, 'RANGE_D': 5, 'CONTRIB': 1, 'template': None, 'mat': None}"]

# %%
layer_dict = {l.name:l for l in model.layers}

# %%
np.around(layer_dict['conv_k0'].get_weights()[0],3)
# Out:
# array([[[-1.183],
#         [-0.427],
#         [-0.266],
#         [ 0.386]]], dtype=float32)

# %%
np.around(layer_dict['conv_k1'].get_weights()[0],3)
# Out:
# array([[[-0.069],
#         [-0.172],
#         [-0.655],
#         [ 0.523]]], dtype=float32)

# %%
x_test_b = mb.blockify_seq_ohe(x_test)
y_hat = model.predict(x_test_b).flatten()
h = sns.jointplot(y_test, y_hat)
h.set_axis_labels("obs", "pred", fontsize=16)
print("spearman", ss.spearmanr(y_hat, y_test))
p = ss.pearsonr(y_hat, y_test)
print("pearson", p)
h.fig.suptitle("Testing prediction, pcc=%.3f"%p[0], fontsize=16)
# Out:
# spearman SpearmanrResult(correlation=0.932868488747965, pvalue=0.0)
# pearson (0.9429342383098863, 0.0)
# Text(0.5, 0.98, 'Testing prediction, pcc=0.943')
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Mon Sep 05 2022
#
# Python implementation: CPython
# Python version       : 3.7.9
# IPython version      : 7.22.0
#
# tensorflow: 1.15.0
# numpy     : 1.21.6
# yaml      : 5.4.1
# scipy     : 1.7.3
# seaborn   : 0.11.1
# matplotlib: 3.4.3
# amber     : 0.1.2-pmbga
# pandas    : 1.3.5
#
# Watermark: 2.3.1
